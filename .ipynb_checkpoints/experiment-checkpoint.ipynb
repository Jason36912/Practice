# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_csv('E:\zuoye\\ex3.csv',skiprows=2, header=None, names = ['a','b'])
df = pd.read_csv('E:\zuoye\\ex3.csv',skiprows=2)
df.columns = ['a','b']
df
# Out:
#        a         b
# 0    700  0.063474
# 1    695  0.065845
# 2    690  0.066691
# 3    685  0.069062
# 4    680  0.070666
# 5    675  0.073353
# 6    670  0.075374
# 7    665  0.077981
# 8    660  0.081106
# 9    655  0.085019
# 10   650  0.088732
# 11   645  0.095141
# 12   640  0.099089
# 13   635  0.104672
# 14   630  0.110300
# 15   625  0.117714
# 16   620  0.126564
# 17   615  0.136773
# 18   610  0.148286
# 19   605  0.159753
# 20   600  0.176038
# 21   595  0.192266
# 22   590  0.212779
# 23   585  0.234351
# 24   580  0.261509
# 25   575  0.292743
# 26   570  0.327489
# 27   565  0.368142
# 28   560  0.415055
# 29   555  0.463995
# ..   ...       ...
# 71   345  0.529737
# 72   340  0.534060
# 73   335  0.540828
# 74   330  0.548486
# 75   325  0.558167
# 76   320  0.570136
# 77   315  0.582379
# 78   310  0.598145
# 79   305  0.615111
# 80   300  0.633240
# 81   295  0.654870
# 82   290  0.677058
# 83   285  0.702496
# 84   280  0.732577
# 85   275  0.764527
# ...

# %%
plt.plot(df['a'],df['b'],'r-')
plt.show()
