# %%
import pandas as pd

# %%
for H1 in range(1,74,3):
        H2=H1+2
        fold = '04'
        leavetype = 'BYK'
        #filename = ['H:/BYK/Spectra/',fold, '/averspectra- ', str(H1), '-', str(H2), '.csv']  #这种结果是list
        filename = 'H:/'+leavetype+'/Spectra/'+fold+ '/averspectra-'+ str(H1)+ '-'+str(H2)+ '.csv'
        #filename = 'H:/BYK/Spectra/02/averspectra-1-3.csv'
        df  = pd.read_csv(filename,header=None)
        df.to_csv('H:/'+leavetype+'/Spectra/'+fold+'/'+leavetype+fold+'avg.csv', mode='a', header=False,index=None)
        df = None
# 还可以改进，例如有原始文件删去，本程序只能在原excel里继续添加，需要手动删去

# %%
filename = 'H:/BYK/Spectra/02/averspectra-1-3.csv'
type(filename)
# Out:
# str

# %%
for H1 in range(1,52,3):
    print(H1)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49

# %%
for H1 in range(1,74,3):
        H2=H1+2
        fold = '01'
        leavetype = 'BYK'
        #filename = ['H:/BYK/Spectra/',fold, '/averspectra- ', str(H1), '-', str(H2), '.csv']  #这种结果是list，路径应该为str
        filename = 'H:/'+leavetype+'/Spectra/'+fold+ '/averspectra-'+ str(H1)+ '-'+str(H2)+ '.csv'
        df  = pd.read_csv(filename,header=None)
        df.to_csv('H:/'+leavetype+'/Spectra/'+fold+'/'+leavetype+fold+'avg.csv', mode='a', header=False,index=None)
        df = None

# %%
df.to_csv('my_csv.csv', mode='a', header=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8e6eda2a6a99> in <module>
# ----> 1 df.to_csv('my_csv.csv', mode='a', header=False)
#
# NameError: name 'df' is not defined

# %%
data = pd.read_csv('H:\\CK\\Spectra\\02\\CK02avg.csv',header=None)
data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.051220  0.052059  0.053486  0.055505  0.058085  0.061165  0.064576
# 1  0.191040  0.194590  0.200540  0.208650  0.218560  0.229780  0.241870
# 2  0.076781  0.077800  0.079681  0.082356  0.085781  0.089799  0.094224
# 3  0.078924  0.079717  0.081162  0.083143  0.085538  0.088737  0.091950
# 4  0.068864  0.069780  0.071468  0.073863  0.076924  0.080515  0.084460
#
#         7         8         9    ...      340      341      342      343  \
# 0  0.068086  0.071778  0.075485  ...  0.51600  0.51560  0.51519  0.51485
# 1  0.254320  0.266750  0.279030  ...  0.61733  0.61695  0.61654  0.61612
# 2  0.098881  0.103610  0.108430  ...  0.50814  0.50790  0.50759  0.50719
# 3  0.095465  0.099005  0.102630  ...  0.54303  0.54263  0.54229  0.54187
# 4  0.088607  0.092812  0.097107  ...  0.56631  0.56593  0.56558  0.56514
#
#        344      345      346      347      348      349
# ...

# %%
import seaborn as sns
def avgplot(data):
    for i in data.index:
        if i is not False:
            sns.lineplot(range(350),data.iloc[i,:])
avgplot(data)

# %%
data = pd.read_csv('H:\\BYK\\Spectra\\02\\BYK02avg.csv',header=None)
avgplot(data)
